# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('new_redbus_bus_data.db', timeout=30)
df = pd.read_sql_query("SELECT * FROM bus_details", conn)
df.head(5)
# Out:
#    id Corporation_Name                     Route_Name  \
# 0  11            RSRTC               Jodhpur to Ajmer
# 1  45            RSRTC  Jodhpur to Beawar (Rajasthan)
# 2  46            RSRTC  Jodhpur to Beawar (Rajasthan)
# 3  47            RSRTC  Jodhpur to Beawar (Rajasthan)
# 4  53            RSRTC   Jaipur (Rajasthan) to Pilani
#
#                                           Route_Link           Bus_Name  \
# 0  https://www.redbus.in/bus-tickets/jodhpur-to-a...   V k jain travels
# 1  https://www.redbus.in/bus-tickets/jodhpur-to-b...   V k jain travels
# 2  https://www.redbus.in/bus-tickets/jodhpur-to-b...  Jain travels regd
# 3  https://www.redbus.in/bus-tickets/jodhpur-to-b...  Jain travels regd
# 4  https://www.redbus.in/bus-tickets/jaipur-to-pi...       Amit Travels
#
#                         Bus_Type Departing_Time Duration Reaching_Time  \
# 0  NON A/C Seater/ Sleeper (2+1)          09:00  04h 50m         13:50
# 1  NON A/C Seater/ Sleeper (2+1)          09:00  03h 35m         12:35
# 2          NON A/C Sleeper (2+1)          11:00  03h 40m         14:40
# 3     A/C Seater / Sleeper (2+1)          14:00  03h 20m         17:20
# 4               A/C Seater (2+3)          10:50  05h 40m         16:30
#
#    Star_Rating  Price  Seat_Availability     Scrape_Timestamp
# 0          5.0  330.0                 36  2024-10-26 08:55:55
# 1          3.0  270.0                 35  2024-10-26 08:56:48
# 2          4.7  430.0                 29  2024-10-26 08:56:48
# 3          4.7  370.0                 39  2024-10-26 08:56:48
# 4          2.9  349.0                 34  2024-10-26 08:56:55

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13015 entries, 0 to 13014
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 13015 non-null  int64
#  1   Corporation_Name   13015 non-null  object
#  2   Route_Name         13015 non-null  object
#  3   Route_Link         13015 non-null  object
#  4   Bus_Name           13015 non-null  object
#  5   Bus_Type           13015 non-null  object
#  6   Departing_Time     13015 non-null  object
#  7   Duration           13015 non-null  object
#  8   Reaching_Time      13015 non-null  object
#  9   Star_Rating        13015 non-null  float64
#  10  Price              13015 non-null  float64
#  11  Seat_Availability  13015 non-null  int64
#  12  Scrape_Timestamp   13015 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 1.3+ MB
